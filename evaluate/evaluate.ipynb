# %%
print("Sequential(380) with 0.8 0.2")
# !python eval.py --fake-threshold 0.9 --real-threshold 0.1 --result-path "380" --answer-json "output.json"
# Out:
# Sequential(380) with 0.8 0.2
# ['aaapwqhxli.mp4', '0.1945142149925232']
# ['aabqcugcpc.mp4', '0.12303728610277176']
# ['aabyjxwqyo.mp4', '0.9610578417778015']
# ['aacehwwzol.mp4', '0.7087783813476562']
# ['aacmrrcpmr.mp4', '0.9698572158813477']
# ['aacweweyzz.mp4', '0.8908442854881287']
# ['aadvqhdtxl.mp4', '0.9788808822631836']
# ['aaeflzzhvy.mp4', '0.9890864491462708']
# ['aaeucwtkdx.mp4', '0.989276647567749']
# ['aaferzprat.mp4', '0.31358373165130615']
# ['aafuphyhpt.mp4', '0.9840216040611267']
# ['aaghqpewzx.mp4', '0.9819208383560181']
# ['aagsmskgyw.mp4', '0.9079307317733765']
# ['aagundkpoh.mp4', '0.9796931147575378']
# ['aahkgsltxw.mp4', '0.9536521434783936']
# ['aahzjreawd.mp4', '0.9896620512008667']
# ['aaiqsitvnd.mp4', '0.9899685978889465']
# ['aaivbtdyjn.mp4', '0.13503462076187134']
# ['aaixesxaoj.mp4', '0.9407157897949219']
# ['aajnpdqnlz.mp4', '0.21539704501628876']
# ['aakjdfqwnu.mp4', '0.9706655144691467']
# ['aakjukgjme.mp4', '0.5928314924240112']
# ...

# %%
print("Sequential(380) with 0.8 0.2")
# !python eval.py --fake-threshold 0.9 --real-threshold 0.1 --result-path "416" --answer-json "output.json"
# Out:
# Sequential(380) with 0.8 0.2
# ['aaapwqhxli.mp4', '0.21675166487693787']
# ['aabqcugcpc.mp4', '0.07815705984830856']
# ['aabyjxwqyo.mp4', '0.9750593304634094']
# ['aacehwwzol.mp4', '0.6870114207267761']
# ['aacmrrcpmr.mp4', '0.9702615737915039']
# ['aacweweyzz.mp4', '0.8638912439346313']
# ['aadvqhdtxl.mp4', '0.9743332862854004']
# ['aaeflzzhvy.mp4', '0.9895572066307068']
# ['aaeucwtkdx.mp4', '0.9866057634353638']
# ['aaferzprat.mp4', '0.4800380766391754']
# ['aafuphyhpt.mp4', '0.9634392857551575']
# ['aaghqpewzx.mp4', '0.9702150821685791']
# ['aagsmskgyw.mp4', '0.8249461054801941']
# ['aagundkpoh.mp4', '0.9635239243507385']
# ['aahkgsltxw.mp4', '0.9509206414222717']
# ['aahzjreawd.mp4', '0.9885697960853577']
# ['aaiqsitvnd.mp4', '0.9890307188034058']
# ['aaivbtdyjn.mp4', '0.08648480474948883']
# ['aaixesxaoj.mp4', '0.9028337001800537']
# ['aajnpdqnlz.mp4', '0.20800311863422394']
# ['aakjdfqwnu.mp4', '0.9430705904960632']
# ['aakjukgjme.mp4', '0.8861684203147888']
# ...
